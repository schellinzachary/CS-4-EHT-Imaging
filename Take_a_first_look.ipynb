# %% [markdown]
# ### Having a first look (07.12.22)

# %% [markdown]
# First look at this repository https://github.com/achael/eht-imaging
#
# It is quite old (last commit in Oct. 20) but for a first assesment and experimantation more then enough.
#
# There is also a presentation (linked in the git: https://www.dropbox.com/s/7533ucj8bt54yh7/Bouman_Chael.pdf?dl=0 ) explaining the data download procedure, the data format and their library for plotting, manipulation of data and their maximum likelihood approach and first steps. This notebook follows that presentation.
#
# The first steps include the installation of their python library (explained in the git repository) and the download of simulated/real data (info in the presentation).

# %%
import numpy as np
import ehtim as eh

# %%
# Load the observation file
obs = eh.obsdata.load_uvfits("./data/myDataResults_6312/data/sgraimage.uvfits")
# Out:
# Loading uvfits:  ./data/myDataResults_6312/data/sgraimage.uvfits
# POLREP_UVFITS: circ
# Number of uvfits Correlation Products: 4
# No NX table in uvfits!

# %%
# Look at plots in the UV range<3
obs.plotall("u","v", conj=True) # conj=True schows u, v and u-v, Not shure what the difference is by now (07.12.22).
# Out:
# <AxesSubplot: xlabel='$u$', ylabel='$v$'>

# %%
# Look at plots in the "visibility amplitudes"
obs.plotall("uvdist","amp") # Other keywords are possible: "shr","sigma","gamp","uamp","vamp","m". Not shure what the difference is by now (07.12.22).
# Out:
# <AxesSubplot: xlabel='$u-v$ Distance', ylabel='Amplitude'>
